# %%
import os
rang = len(os.listdir(r"C:\Users\pc\OneDrive_GTU\OneDrive - Gebze Teknik Üniversitesi\Tez\Proje\models2"))

# %%
files =["Default", "Default_TRIAD", "No_Dissipation", "No_Dissipation_TRIAD"]

# %%
for fn in range(rang):
    file_nb = fn
    for fn in range(len(files)):
        PALL_file = files[fn]
        model_file = files[fn]
        os.chdir(r"C:\Users\pc\OneDrive_GTU\OneDrive - Gebze Teknik Üniversitesi\Tez\Proje\Dissipation Projects\11 - Herbers et al. (2006) - (DUCK94)\IPYNBs\Create_Result_PY")
        # %run MODEL_Results_20_07_2022.ipynb
        #%run MODEL_Results_Dec_22_BKD.ipynb
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 78BF-2C1B
#
#  Directory of C:\Users\pc\OneDrive_GTU\OneDrive - Gebze Teknik šniversitesi\Tez\Proje\models2\model_11010100
#
# 12.12.2022  15:33    <DIR>          .
# 12.12.2022  15:33    <DIR>          ..
# 12.12.2022  15:32            31.208 19941026.xlsx_bottom.xlsx
# 12.12.2022  15:33             3.193 Default.prt
# 12.12.2022  15:33            17.455 Default.sp1
# 12.12.2022  15:33           889.888 Default.sp2
# 12.12.2022  15:32             1.177 Default.SWN
# 12.12.2022  15:33             3.204 Default_TRIAD.prt
# 12.12.2022  15:33            17.455 Default_TRIAD.sp1
# 12.12.2022  15:33           889.888 Default_TRIAD.sp2
# 12.12.2022  15:32             1.191 Default_TRIAD.SWN
# 12.12.2022  15:33             3.171 No_Dissipation.prt
# 12.12.2022  15:33            17.455 No_Dissipation.sp1
# 12.12.2022  15:33           889.888 No_Dissipation.sp2
# 12.12.2022  15:32             1.193 No_Dissipation.SWN
# ...
