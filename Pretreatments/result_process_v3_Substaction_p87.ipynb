# %% [markdown]
# # Libraries & GDrive

# %%
folder_nb = 0

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt

# %% [markdown]
# The folder which will read spectrum files.

# %%
parent_dir = "/gdrive/My Drive/YL TEZ/py/swan_models/new_models"

# %%
os.chdir(parent_dir)

# %%
mdate = os.listdir()[folder_nb]
if not mdate == "Spectrums" or mdate == "Profiles_Excel":
  date = mdate[6:]
else:
  folder_nb += 1

# %%
os.chdir("/gdrive/My Drive/YL TEZ/py/swan_models/new_models/Spectrums")

# %%
file_name = date + "_Fit_Data.xlsx"

# %% [markdown]
# # Determine boundary sensor

# %%
spec_file = pd.ExcelFile(file_name)

# %%
p87 = date + ".ppp87"
p19 = date + ".ppp19"
p18 = date + ".ppp18"
p45 = date + ".ppp45"
p17 = date + ".ppp17"
p15 = date + ".ppp15"
p16 = date + ".ppp16"
p14 = date + ".ppp14"
p13 = date + ".ppp13"
p12 = date + ".ppp12"
p26 = date + ".ppp26"
p23 = date + ".ppp23"
p05 = date + ".ppp05"
p04 = date + ".ppp04"
p03 = date + ".ppp03"
p02 = date + ".ppp02"
p01 = date + ".ppp01"

# %%
if p87 in spec_file.sheet_names:
  sheetname = p87
  boun_loc = "-884.1100"
elif p19 in spec_file.sheet_names:
  sheetname = p19
  boun_loc = "-480.3400"
elif p18 in spec_file.sheet_names:
  sheetname = p18
  boun_loc = "-398.3900"
elif p45 in spec_file.sheet_names:
  sheetname = p45
  boun_loc = "-370.0800"
elif p17 in spec_file.sheet_names:
  sheetname = p17
  boun_loc = "-320.3700"
elif p15 in spec_file.sheet_names:
  sheetname = p15
  boun_loc = "-264.7000"
elif p16 in spec_file.sheet_names:
  sheetname = p16
  boun_loc = "-252.0300"
elif p14 in spec_file.sheet_names:
  sheetname = p14
  boun_loc = "-240.55000"
elif p13 in spec_file.sheet_names:
  sheetname = p13
  boun_loc = "-220.2300"
elif p12 in spec_file.sheet_names:
  sheetname = p12
  boun_loc = "-205.3400"
elif p26 in spec_file.sheet_names:
  sheetname = p26
  boun_loc = "-190.2000"
elif p23 in spec_file.sheet_names:
  sheetname = p23
  boun_loc = "-190.2000"
elif p05 in spec_file.sheet_names:
  sheetname = p05
  boun_loc = "-169.5000"
elif p04 in spec_file.sheet_names:
  sheetname = p04
  boun_loc = "-160.7700"
elif p03 in spec_file.sheet_names:
  sheetname = p03
  boun_loc = "-145.4200"
elif p02 in spec_file.sheet_names:
  sheetname = p02
  boun_loc = "-135.0100"
elif p01 in spec_file.sheet_names:
  sheetname = p01
  boun_loc = "-124.9400"
print("Boundary sensor name:\t \t", sheetname)
print("Boundary sensor location(x):\t", boun_loc)
# Out:
# Boundary sensor name:	 	 09260100.ppp87
# Boundary sensor location(x):	 -884.1100

# %% [markdown]
# # Read Spectrum Files

# %%
boundary_sensor = sheetname

# %%
os.mkdir(parent_dir + '/' + 'model_' + date + '/' + 'Results')

# %%
os.mkdir(parent_dir + '/' + 'model_' + date + '/' + 'Results' + '/' + 'substaction_from_boundary_sensor')

# %% [markdown]
# Read DATE_Fit_Data.xlsx

# %%
# !pip install XlsxWriter
# Out:
# Collecting XlsxWriter
#   Downloading XlsxWriter-3.0.2-py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 5.2 MB/s
# Installing collected packages: XlsxWriter
# Successfully installed XlsxWriter-3.0.2

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(parent_dir + '/' + 'model_' + date + '/' + 'Results'+ '/' + 'substaction_from_boundary_sensor' + '/' + date + "_substaction_" + boundary_sensor[11:] + ".xlsx", engine='xlsxwriter')

# %%
xls = pd.ExcelFile(path_)
sheets = xls.sheet_names
boun = pd.read_excel(xls, boundary_sensor, index_col=0)
for j in range(len(sheets)):
  if not sheets[j] == boundary_sensor:
    df = pd.read_excel(xls, sheets[j], index_col=0)
    subs = df.iloc[:, 0:1]
    subs["Substaction"] = df.iloc[:, 2] - boun.iloc[:, 2]
    subs.to_excel(writer, sheet_name=boundary_sensor[9:] + " - " + sheets[j][9:])
    #fig, ax = plt.subplots()
    plt.plot(df.iloc[:, 0].values, subs["Substaction"].values)
    plt.title(boundary_sensor[9:] + " - " + sheets[j][9:])
    #ax.grid(axis='both')
    #plt.tight_layout()
    #plt.figure(figsize=(15,10))
    plt.savefig(parent_dir + '/' + 'model_' + date + '/' + 'Results'+ '/' + 'substaction_from_boundary_sensor' + '/' + boundary_sensor[9:] + " - " + sheets[j][9:] + ".png")
    plt.show()
writer.save()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig, ax = plt.subplots()
plt.plot(df.iloc[:, 0].values, subs["Substaction"].values)
plt.title(boundary_sensor[9:] + " - " + sheets[j][9:])
ax.grid(axis='both')
plt.tight_layout()
plt.figure(figsize=(15,10))
plt.show()

# %%
folder_nb += 1
folder_nb
# Out:
# 1
