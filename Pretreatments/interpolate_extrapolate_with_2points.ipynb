# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/MyDrive/YL TEZ/
# %ls
# Out:
# /gdrive/MyDrive/YL TEZ
#  Makale/   test04.02/            yeni_model_30_Ocak/
#  py/       Wave_Spectrum.ipynb  'Zbilimsel etik ödev'/

# %%
# %cd /gdrive/MyDrive/YL TEZ/yeni_model_30_Ocak/
# %ls
# Out:
# /gdrive/MyDrive/YL TEZ/yeni_model_30_Ocak
#  08031300/                      'ppp19 - ppp16.png'
#  08031300_Fit_Data.xlsx         'ppp19 - ppp17.png'
#  08031300_substaction_p19.xlsx  'ppp19 - ppp18.png'
#  gauge_locations.csv            'ppp19 - ppp45.png'
#  PALL.sp1                        result_multiple_sheet.xlsx
# 'ppp19 - ppp05.png'              Results.xlsx
# 'ppp19 - ppp12.png'              tail.xlsx
# 'ppp19 - ppp13.png'              test.csv
# 'ppp19 - ppp14.png'              test_result.xlsx
# 'ppp19 - ppp15.png'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import interpolate
x = np.array([438, 873.839])
y = np.array([-4.734305785, -7.864])
f = interpolate.interp1d(x, y, fill_value='extrapolate')

# %%
xnew = np.arange(436, 886, 1)
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %%
dat1={'x':xnew, 'z':ynew}
tail1=pd.DataFrame(data=dat1)
tail1.to_excel("tail00.xlsx")
tail1
# Out:
#        x         z
# 0    436 -4.719944
# 1    437 -4.727125
# 2    438 -4.734306
# 3    439 -4.741487
# 4    440 -4.748667
# ..   ...       ...
# 445  881 -7.915422
# 446  882 -7.922603
# 447  883 -7.929784
# 448  884 -7.936965
# 449  885 -7.944145
#
# [450 rows x 2 columns]
