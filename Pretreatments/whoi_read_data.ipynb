# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import os
os.chdir('/gdrive/My Drive/YL TEZ/py/data_whoi/Spectra/08170100')

# %%
# !ls
# Out:
# 08170100.ppp02	     08170100.ppp05  08170100.ppp15  08170100.ppp23
# 08170100_ppp02.xlsx  08170100.ppp12  08170100.ppp17  08170100.ppp45
# 08170100.ppp03	     08170100.ppp13  08170100.ppp18  08170100.ppp87
# 08170100.ppp04	     08170100.ppp14  08170100.ppp19  08170100_ppp87.xlsx

# %%
import pandas as pd

# %%
da =  pd.read_csv("08170100.ppp87", sep='.',
                         names=['BAND','FREQ', 'PP', 'PSSE'])
df = da.iloc[3:,:]
df
# Out:
#          BAND    FREQ        PP          PSSE
# 3        1     0078    354000.0  3.540000e+05
# 4        2     0127     22200.0  2.220000e+04
# 5        3     0176     18900.0  1.900000e+04
# 6        4     0225     22800.0  2.300000e+04
# 7        5     0273     26000.0  2.640000e+04
# ..        ...     ...       ...           ...
# 202    200     9795        21.5  3.450000e+27
# 203    201     9844        23.8  7.070000e+27
# 204    202     9893        20.3  1.130000e+28
# 205    203     9941        22.1  2.180000e+28
# 206    204     9990        23.7  4.610000e+28
#
# [204 rows x 4 columns]

# %%
df2 = df.iloc[:, 2:4]
df2 = df2.multiply(0.001)
df3 = df["BAND"]+df["FREQ"]

# %%
df["PP"] = df2["PP"]
df["PSSE"] = df2["PSSE"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#          BAND    FREQ        PP          PSSE
# 3        1     0078    354.0000  3.540000e+02
# 4        2     0127     22.2000  2.220000e+01
# 5        3     0176     18.9000  1.900000e+01
# 6        4     0225     22.8000  2.300000e+01
# 7        5     0273     26.0000  2.640000e+01
# ..        ...     ...       ...           ...
# 202    200     9795      0.0215  3.450000e+24
# 203    201     9844      0.0238  7.070000e+24
# 204    202     9893      0.0203  1.130000e+25
# 205    203     9941      0.0221  2.180000e+25
# 206    204     9990      0.0237  4.610000e+25
#
# [204 rows x 4 columns]

# %%
read_file = "08170100.ppp87"
da =  pd.read_csv(read_file, sep='.', names=['BAND','FREQ', 'PP', 'PSSE'])
df = da.iloc[3:,:]


df2 = df.iloc[:, 2:4]
df2 = df2.multiply(0.001)
df3 = df["BAND"]+df["FREQ"]

df["PP"] = df2["PP"]
df["PSSE"] = df2["PSSE"]
kkk = ["BAND","FREQ", "PSSE"]
df[kkk]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
#          BAND    FREQ          PSSE
# 3        1     0078    3.540000e+02
# 4        2     0127    2.220000e+01
# 5        3     0176    1.900000e+01
# ...

# %%
# %ls
# Out:
# 08170100.ppp02       08170100.ppp05  08170100.ppp15  08170100.ppp23
# 08170100_ppp02.xlsx  08170100.ppp12  08170100.ppp17  08170100.ppp45
# 08170100.ppp03       08170100.ppp13  08170100.ppp18  08170100.ppp87
# 08170100.ppp04       08170100.ppp14  08170100.ppp19  08170100_ppp87.xlsx

# %%
filename = ["08170100.ppp02","08170100.ppp05","08170100.ppp15","08170100.ppp23","08170100.ppp12","08170100.ppp17","08170100.ppp45","08170100.ppp03","08170100.ppp13","08170100.ppp18","08170100.ppp87","08170100.ppp04","08170100.ppp14","08170100.ppp19"]
filename

# %%
fd = []
for i in range(13):
  da =  pd.read_csv(filename[i], sep='.', names=['BAND','FREQ', 'PP', 'PSSE'])
  da = da.iloc[3:, :]
  df2 = da.iloc[:, 2:4]
  df2 = da.multiply(0.001)
  df3 = df["BAND"]+df["FREQ"]

df["PP"] = df2["PP"]
df["PSSE"] = df2["PSSE"]
df
  print(da)

# %%
for filename in os.listdir("08170100"):
   with open(os.path.join("08170100", filename), 'r') as f:
       text = f.read()
       print(text)

# %%
# %ls

# %%
# %cd 08170100
# %ls
# Out:
# /gdrive/My Drive/YL TEZ/py/data_whoi/Spectra/08170100
# 08170100.ppp02       08170100.ppp05  08170100.ppp15  08170100.ppp23
# 08170100_ppp02.xlsx  08170100.ppp12  08170100.ppp17  08170100.ppp45
# 08170100.ppp03       08170100.ppp13  08170100.ppp18  08170100.ppp87
# 08170100.ppp04       08170100.ppp14  08170100.ppp19  08170100_ppp87.xlsx

# %%
# %ls
os.lostdir("/gdrive/My Drive/YL TEZ/py/data_whoi/Spectra/08170100")
# %ls
# Out:
# 08170100.ppp02       08170100.ppp05  08170100.ppp15  08170100.ppp23
# 08170100_ppp02.xlsx  08170100.ppp12  08170100.ppp17  08170100.ppp45
# 08170100.ppp03       08170100.ppp13  08170100.ppp18  08170100.ppp87
# 08170100.ppp04       08170100.ppp14  08170100.ppp19  08170100_ppp87.xlsx
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-f60a71e341e9> in <module>()
#       1 get_ipython().magic('ls')
# ----> 2 os.lostdir("/gdrive/My Drive/YL TEZ/py/data_whoi/Spectra/08170100")
#       3 get_ipython().magic('ls')
#
# AttributeError: module 'os' has no attribute 'lostdir'

# %%
dfs = []
for filename in os.listdir("/gdrive/My Drive/YL TEZ/py/data_whoi/Spectra/08170100"):
  print(filename)
  df = pd.read_csv(filename).encode('utf-8').strip()
df
# Out:
# 08170100.ppp02
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-19b1faaae645> in <module>()
#       2 for filename in os.listdir("/gdrive/My Drive/YL TEZ/py/data_whoi/Spectra/08170100"):
#       3   print(filename)
# ----> 4   df = pd.read_csv(filename).encode('utf-8').strip()
#       5 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'encode'

# %%
df.to_excel("08170100_ppp87.xlsx")
