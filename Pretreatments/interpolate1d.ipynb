# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
# %cd MyDrive/YL TEZ/py/data_whoi/FRF
# %ls *xlsx
# Out:
# [Errno 2] No such file or directory: 'MyDrive/YL TEZ/py/data_whoi/FRF'
# /gdrive/MyDrive/YL TEZ/py/data_whoi/FRF
# 19940803.xlsx          19940914.xlsx  19941006.xlsx  19941017.xlsx
# 19940810.xlsx          19940916.xlsx  19941007.xlsx  19941018.xlsx
# 19940812.xlsx          19940920.xlsx  19941008.xlsx  19941019.xlsx
# 19940814_FRF-new.xlsx  19940921.xlsx  19941009.xlsx  19941020.xlsx
# 19940814.xlsx          19940924.xlsx  19941010.xlsx  19941021.xlsx
# 19940816.xlsx          19940926.xlsx  19941011.xlsx  19941026.xlsx
# 19940818.xlsx          19940928.xlsx  19941012.xlsx  19941109.xlsx
# 19940820.xlsx          19940930.xlsx  19941013.xlsx  19941121.xlsx
# 19940825.xlsx          19941003.xlsx  19941014.xlsx
# 19940907.xlsx          19941004.xlsx  19941015.xlsx
# 19940909.xlsx          19941005.xlsx  19941016.xlsx

# %%
import pandas as pd

# %%
df = pd.read_excel('19940825.xlsx', index_col=None)
df = df.iloc[:,:]

# %%
df

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import interpolate
from scipy.interpolate import interp1d
#x = df.iloc[:, 0:1]
#y = df.iloc[:, 1:2]
x = np.arange(76, 433, 1)

x_veri = df.x.values
d_veri = df.d.values


f = interpolate.interp1d(x_veri, d_veri, kind='linear')

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import interpolate
from scipy.interpolate import interp1d

#x = np.arange(130, 884, 1)
d = f(x)

# %%
y_orjinal = df.iloc[373:,1:2].values.flatten()
len(y_orjinal)
# Out:
# 0

# %%
len(d)
# Out:
# 357

# %%
plt.scatter(x,d)
plt.show()

# %%
prof1={'x':x, 'z':d}



profile1=pd.DataFrame(data=prof1)



profile1.to_excel("profile2.xlsx")
